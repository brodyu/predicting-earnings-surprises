# %%
import time
import pandas as pd
import requests
import json
import concurrent.futures
from decouple import config

# Disable warnings
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
def get_jsonparsed_data(url):
    """
    Sends a GET request to FMP's Earning Surprise API and returns the resulting data in a dictionary
    """
    # sending get request and saving the response as response object
    response = requests.get(url=url)
    data = json.loads(response.text)
    return data

# %%
# Read in nasdaq data and extract symbols column
nasdaq_list = pd.read_csv("nasdaq_list.csv")
# Pull API key from .env file
FMP_API_KEY = config("FMP_API_KEY")

nasdaq_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8202 entries, 0 to 8201
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      8202 non-null   object
#  1   Name        8202 non-null   object
#  2   Market Cap  7729 non-null   float64
#  3   Country     7458 non-null   object
#  4   IPO Year    4820 non-null   float64
#  5   Sector      6178 non-null   object
#  6   Industry    6195 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 448.7+ KB

# %%
# Filter missing out rows with missing data
# Filter reduces dataset from 8202 entries to 3156 entries
nasdaq_list_filtered = nasdaq_list.dropna()
nasdaq_list_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3156 entries, 0 to 8200
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      3156 non-null   object
#  1   Name        3156 non-null   object
#  2   Market Cap  3156 non-null   float64
#  3   Country     3156 non-null   object
#  4   IPO Year    3156 non-null   float64
#  5   Sector      3156 non-null   object
#  6   Industry    3156 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 197.2+ KB

# %%
symbols = nasdaq_list_filtered.Symbol

url_list = []
for idx, val in enumerate(symbols):
    url = "https://financialmodelingprep.com/api/v3/historical/earning_calendar/{}?limit=80&apikey={}".format(val, FMP_API_KEY)
    url_list.append(url)

# %%
# Call FMP API for each URL using Concurrent library
# Run takes 211 seconds ... be patient
with concurrent.futures.ThreadPoolExecutor() as executor:
    res = [executor.submit(get_jsonparsed_data, url) for url in url_list]
    concurrent.futures.wait(res)

# %%
res[3].result()
# Out:
# [{'date': '2021-10-28',
#   'symbol': 'AAPL',
#   'eps': 1.24,
#   'epsEstimated': 1.24,
#   'time': 'amc',
#   'revenue': 83360000000.0,
#   'revenueEstimated': 117986000000.0},
#  {'date': '2021-07-27',
#   'symbol': 'AAPL',
#   'eps': 1.3,
#   'epsEstimated': 1.0,
#   'time': 'amc',
#   'revenue': 81434000000.0,
#   'revenueEstimated': 84581900000.0},
#  {'date': '2021-04-28',
#   'symbol': 'AAPL',
#   'eps': 1.4,
#   'epsEstimated': 0.99,
#   'time': 'amc',
#   'revenue': 89584000000.0,
#   'revenueEstimated': 76920700000.0},
#  {'date': '2021-01-27',
#   'symbol': 'AAPL',
#   'eps': 1.68,
#   'epsEstimated': 1.41,
#   'time': 'amc',
#   'revenue': 111439000000.0,
#   'revenueEstimated': 90099617021},
#  {'date': '2020-10-29',
#   'symbol': 'AAPL',
#   'eps': 0.73,
#   'epsEstimated': 0.7,
#   'time': 'amc',
#   'revenue': 64698000000.0,
#   'revenueEstimated': 62039178082.19178},
#  {'date': '2020-07-30',
#   'symbol': 'AAPL',
#   'eps': 0.65,
#   'epsEstimated': 0.51,
#   'time': 'amc',
#   'revenue': 59685000000.0,
#   'revenueEstimated': 46829769230.76923},
#  {'date': '2020-04-30',
#   'symbol': 'AAPL',
#   'eps': 0.64,
#   'epsEstimated': 0.56,
#   'time': 'amc',
#   'revenue': 58313000000.0,
#   'revenueEstimated': 51023875000.00001},
#  {'date': '2020-01-28',
#   'symbol': 'AAPL',
#   'eps': 1.25,
#   'epsEstimated': 1.14,
#   'time': 'amc',
#   'revenue': 91819000000.0,
#   'revenueEstimated': 83738928000.0},
#  {'date': '2019-10-30',
#   'symbol': 'AAPL',
#   'eps': 0.76,
#   'epsEstimated': 0.71,
#   'time': 'amc',
#   'revenue': 64040000000.0,
#   'revenueEstimated': 59826842105.26315},
#  {'date': '2019-07-30',
#   'symbol': 'AAPL',
#   'eps': 0.55,
#   'epsEstimated': 0.53,
#   'time': 'amc',
#   'revenue': 53809000000.0,
#   'revenueEstimated': 51852309090.90909},
#  {'date': '2019-04-30',
#   'symbol': 'AAPL',
#   'eps': 0.62,
#   'epsEstimated': 0.59,
#   'time': 'amc',
#   'revenue': 58015000000.0,
#   'revenueEstimated': 55207822580.64516},
#  {'date': '2019-01-29',
#   'symbol': 'AAPL',
#   'eps': 1.05,
#   'epsEstimated': 1.04,
#   'time': 'amc',
#   'revenue': 84310000000.0,
#   'revenueEstimated': 83507047619.04762},
#  {'date': '2018-11-01',
#   'symbol': 'AAPL',
#   'eps': 0.73,
#   'epsEstimated': 0.7,
#   'time': 'amc',
#   'revenue': 62900000000.0,
#   'revenueEstimated': 60315068493.15068},
#  {'date': '2018-07-31',
#   'symbol': 'AAPL',
#   'eps': 0.585,
#   'epsEstimated': 0.545,
#   'time': 'amc',
#   'revenue': 53265000000.0,
#   'revenueEstimated': 49622948717.94872},
#  {'date': '2018-05-01',
#   'symbol': 'AAPL',
#   'eps': 0.6825,
#   'epsEstimated': 0.6675,
#   'time': 'amc',
#   'revenue': 61137000000.0,
#   'revenueEstimated': 59793329670.329666},
#  {'date': '2018-02-01',
#   'symbol': 'AAPL',
#   'eps': 0.9725,
#   'epsEstimated': 0.965,
#   'time': 'amc',
#   'revenue': 88293000000.0,
#   'revenueEstimated': 87612077120.82262},
#  {'date': '2017-11-02',
#   'symbol': 'AAPL',
#   'eps': 0.5175,
#   'epsEstimated': 0.4675,
#   'time': 'amc',
#   'revenue': 52579000000.0,
#   'revenueEstimated': 47498903381.64252},
#  {'date': '2017-08-01',
#   'symbol': 'AAPL',
#   'eps': 0.4175,
#   'epsEstimated': 0.3925,
#   'time': 'amc',
#   'revenue': 45408000000.0,
#   'revenueEstimated': 42688958083.83234},
#  {'date': '2017-05-02',
#   'symbol': 'AAPL',
#   'eps': 0.525,
#   'epsEstimated': 0.505,
#   'time': 'amc',
#   'revenue': 52896000000.0,
#   'revenueEstimated': 50880914285.71428},
#  {'date': '2017-01-31',
#   'symbol': 'AAPL',
#   'eps': 0.84,
#   'epsEstimated': 0.8025,
#   'time': 'amc',
#   'revenue': 78351000000.0,
#   'revenueEstimated': 74853187500.0},
#  {'date': '2016-10-25',
#   'symbol': 'AAPL',
#   'eps': 0.4175,
#   'epsEstimated': 0.415,
#   'time': 'amc',
#   'revenue': 46852000000.0,
#   'revenueEstimated': 46571449101.7964},
#  {'date': '2016-07-26',
#   'symbol': 'AAPL',
#   'eps': 0.355,
#   'epsEstimated': 0.345,
#   'time': 'amc',
#   'revenue': 42358000000.0,
#   'revenueEstimated': 41164816901.40845},
#  {'date': '2016-04-26',
#   'symbol': 'AAPL',
#   'eps': 0.475,
#   'epsEstimated': 0.5,
#   'time': 'amc',
#   'revenue': 50557000000.0,
#   'revenueEstimated': 53217894736.84212},
#  {'date': '2016-01-26',
#   'symbol': 'AAPL',
#   'eps': 0.82,
#   'epsEstimated': 0.8075,
#   'time': 'amc',
#   'revenue': 75872000000.0,
#   'revenueEstimated': 74715414634.14635},
#  {'date': '2015-10-27',
#   'symbol': 'AAPL',
#   'eps': 0.49,
#   'epsEstimated': 0.47,
#   'time': 'amc',
#   'revenue': 51501000000.0,
#   'revenueEstimated': 49398918367.34694},
#  {'date': '2015-07-21',
#   'symbol': 'AAPL',
#   'eps': 0.4625,
#   'epsEstimated': 0.4525,
#   'time': 'amc',
#   'revenue': 49605000000.0,
#   'revenueEstimated': 48532459459.45946},
#  {'date': '2015-04-27',
#   'symbol': 'AAPL',
#   'eps': 0.5825,
#   'epsEstimated': 0.54,
#   'time': 'amc',
#   'revenue': 58010000000.0,
#   'revenueEstimated': 53777510729.61374},
#  {'date': '2015-01-27',
#   'symbol': 'AAPL',
#   'eps': 0.765,
#   'epsEstimated': 0.65,
#   'time': 'amc',
#   'revenue': 74599000000.0,
#   'revenueEstimated': 63384771241.83006},
#  {'date': '2014-10-20',
#   'symbol': 'AAPL',
#   'eps': 0.355,
#   'epsEstimated': 0.3275,
#   'time': 'amc',
#   'revenue': 42123000000.0,
#   'revenueEstimated': 38859950704.22536},
#  {'date': '2014-07-22',
#   'symbol': 'AAPL',
#   'eps': 0.32,
#   'epsEstimated': 0.3075,
#   'time': 'amc',
#   'revenue': 37432000000.0,
#   'revenueEstimated': 35969812500.0},
#  {'date': '2014-04-23',
#   'symbol': 'AAPL',
#   'eps': 0.415,
#   'epsEstimated': 0.365,
#   'time': 'amc',
#   'revenue': 45646000000.0,
#   'revenueEstimated': 40146481927.710846},
#  {'date': '2014-01-27',
#   'symbol': 'AAPL',
#   'eps': 0.5175,
#   'epsEstimated': 0.5025,
#   'time': 'amc',
#   'revenue': 57594000000.0,
#   'revenueEstimated': 55924608695.652176},
#  {'date': '2013-10-28',
#   'symbol': 'AAPL',
#   'eps': 0.295,
#   'epsEstimated': 0.285,
#   'time': 'amc',
#   'revenue': 37472000000.0,
#   'revenueEstimated': 36201762711.8644},
#  {'date': '2013-07-23',
#   'symbol': 'AAPL',
#   'eps': 0.2675,
#   'epsEstimated': 0.2625,
#   'time': 'amc',
#   'revenue': 35323000000.0,
#   'revenueEstimated': 34662757009.345795},
#  {'date': '2013-04-23',
#   'symbol': 'AAPL',
#   'eps': 0.36,
#   'epsEstimated': 0.3575,
#   'time': 'amc',
#   'revenue': 43603000000.0,
#   'revenueEstimated': 43300201388.88889},
#  {'date': '2013-01-23',
#   'symbol': 'AAPL',
#   'eps': 0.4925,
#   'epsEstimated': 0.48,
#   'time': 'amc',
#   'revenue': 54512000000.0,
#   'revenueEstimated': 53128446700.50761},
#  {'date': '2012-10-25',
#   'symbol': 'AAPL',
#   'eps': 0.31,
#   'epsEstimated': 0.3125,
#   'time': 'amc',
#   'revenue': 35966000000.0,
#   'revenueEstimated': 36256048387.09677},
#  {'date': '2012-07-24',
#   'symbol': 'AAPL',
#   'eps': 0.3325,
#   'epsEstimated': 0.37,
#   'time': 'amc',
#   'revenue': 35023000000.0,
#   'revenueEstimated': 38972962406.01504},
#  {'date': '2012-04-24',
#   'symbol': 'AAPL',
#   'eps': 0.44,
#   'epsEstimated': 0.42,
#   'time': 'amc',
#   'revenue': 39186000000.0,
#   'revenueEstimated': 31838625000.0},
#  {'date': '2012-01-24',
#   'symbol': 'AAPL',
#   'eps': 0.495,
#   'epsEstimated': 0.3625,
#   'time': 'amc',
#   'revenue': 46333000000.0,
#   'revenueEstimated': 33930732323.23232},
#  {'date': '2011-10-18',
#   'symbol': 'AAPL',
#   'eps': 0.2525,
#   'epsEstimated': 0.265,
#   'time': 'amc',
#   'revenue': 28270000000.0,
#   'revenueEstimated': 29669504950.495052},
#  {'date': '2011-07-19',
#   'symbol': 'AAPL',
#   'eps': 0.2775,
#   'epsEstimated': 0.2075,
#   'time': 'amc',
#   'revenue': 28571000000.0,
#   'revenueEstimated': 21363900900.900898},
#  {'date': '2011-04-20',
#   'symbol': 'AAPL',
#   'eps': 0.2275,
#   'epsEstimated': 0.1925,
#   'time': 'amc',
#   'revenue': 24667000000.0,
#   'revenueEstimated': 20872076923.076923},
#  {'date': '2011-01-18',
#   'symbol': 'AAPL',
#   'eps': 0.23,
#   'epsEstimated': 0.1925,
#   'time': 'amc',
#   'revenue': 26741000000.0,
#   'revenueEstimated': 22381054347.826084},
#  {'date': '2010-10-18',
#   'symbol': 'AAPL',
#   'eps': 0.165,
#   'epsEstimated': 0.145,
#   'time': 'amc',
#   'revenue': 20343000000.0,
#   'revenueEstimated': 17877181818.181816},
#  {'date': '2010-07-20',
#   'symbol': 'AAPL',
#   'eps': 0.125,
#   'epsEstimated': 0.11,
#   'time': 'amc',
#   'revenue': 15700000000.0,
#   'revenueEstimated': 13816000000.0},
#  {'date': '2010-04-20',
#   'symbol': 'AAPL',
#   'eps': 0.12,
#   'epsEstimated': 0.0875,
#   'time': 'amc',
#   'revenue': 13499000000.0,
#   'revenueEstimated': 9843020833.333332},
#  {'date': '2010-01-25',
#   'symbol': 'AAPL',
#   'eps': 0.13,
#   'epsEstimated': 0.075,
#   'time': 'amc',
#   'revenue': 15683000000.0,
#   'revenueEstimated': 15526169997.75},
#  {'date': '2009-10-19',
#   'symbol': 'AAPL',
#   'eps': 0.065,
#   'epsEstimated': 0.05,
#   'time': 'amc',
#   'revenue': 12207000000.0,
#   'revenueEstimated': 9390000000.0},
#  {'date': '2009-07-21',
#   'symbol': 'AAPL',
#   'eps': 0.0475,
#   'epsEstimated': 0.0425,
#   'time': 'amc',
#   'revenue': 9734000000.0,
#   'revenueEstimated': 8709368421.052631},
#  {'date': '2009-04-22',
#   'symbol': 'AAPL',
#   'eps': 0.0475,
#   'epsEstimated': 0.04,
#   'time': 'amc',
#   'revenue': 9084000000.0,
#   'revenueEstimated': 7649684210.526316},
#  {'date': '2009-01-21',
#   'symbol': 'AAPL',
#   'eps': 0.0625,
#   'epsEstimated': 0.05,
#   'time': 'amc',
#   'revenue': 11880000000.0,
#   'revenueEstimated': 9504000000.0},
#  {'date': '2008-10-21',
#   'symbol': 'AAPL',
#   'eps': 0.045,
#   'epsEstimated': 0.04,
#   'time': 'amc',
#   'revenue': 11520000000.0,
#   'revenueEstimated': 10240000000.0},
#  {'date': '2008-07-21',
#   'symbol': 'AAPL',
#   'eps': 0.0425,
#   'epsEstimated': 0.0375,
#   'time': 'amc',
#   'revenue': 7561000000.0,
#   'revenueEstimated': 6671470588.235293},
#  {'date': '2008-04-23',
#   'symbol': 'AAPL',
#   'eps': 0.0425,
#   'epsEstimated': 0.0375,
#   'time': 'amc',
#   'revenue': 7980000000.0,
#   'revenueEstimated': 7041176470.588234},
#  {'date': '2008-01-22',
#   'symbol': 'AAPL',
#   'eps': 0.0625,
#   'epsEstimated': 0.0575,
#   'time': 'amc',
#   'revenue': 10430000000.0,
#   'revenueEstimated': 9595600000.0},
#  {'date': '2007-10-22',
#   'symbol': 'AAPL',
#   'eps': 0.035,
#   'epsEstimated': 0.03,
#   'time': 'amc',
#   'revenue': 6606000000.0,
#   'revenueEstimated': 5662285714.285713},
#  {'date': '2007-07-25',
#   'symbol': 'AAPL',
#   'eps': 0.0325,
#   'epsEstimated': 0.025,
#   'time': 'amc',
#   'revenue': 5410000000.0,
#   'revenueEstimated': 4161538461.5384617},
#  {'date': '2007-04-25',
#   'symbol': 'AAPL',
#   'eps': 0.03,
#   'epsEstimated': 0.0225,
#   'time': 'amc',
#   'revenue': 5264000000.0,
#   'revenueEstimated': 3948000000.0},
#  {'date': '2007-01-17',
#   'symbol': 'AAPL',
#   'eps': 0.04,
#   'epsEstimated': 0.0275,
#   'time': 'amc',
#   'revenue': 7123000000.0,
#   'revenueEstimated': 4897062500.0},
#  {'date': '2006-10-18',
#   'symbol': 'AAPL',
#   'eps': 0.0225,
#   'epsEstimated': 0.0175,
#   'time': 'amc',
#   'revenue': 4837000000.0,
#   'revenueEstimated': 7307325000.0},
#  {'date': '2006-07-19',
#   'symbol': 'AAPL',
#   'eps': 0.02,
#   'epsEstimated': 0.015,
#   'time': 'amc',
#   'revenue': 0.0,
#   'revenueEstimated': 0.0},
#  {'date': '2006-04-19',
#   'symbol': 'AAPL',
#   'eps': 0.0175,
#   'epsEstimated': 0.015,
#   'time': 'amc',
#   'revenue': 4359000000.0,
#   'revenueEstimated': 3736285714.2857137},
#  {'date': '2006-01-18',
#   'symbol': 'AAPL',
#   'eps': 0.0225,
#   'epsEstimated': 0.0225,
#   'time': 'amc',
#   'revenue': 5749000000.0,
#   'revenueEstimated': 5749000000.0},
#  {'date': '2005-10-11',
#   'symbol': 'AAPL',
#   'eps': 0.0125,
#   'epsEstimated': 0.0125,
#   'time': 'amc',
#   'revenue': 3678000000.0,
#   'revenueEstimated': 5792850000.0},
#  {'date': '2005-07-13',
#   'symbol': 'AAPL',
#   'eps': 0.0125,
#   'epsEstimated': 0.01,
#   'time': 'amc',
#   'revenue': 3520000000.0,
#   'revenueEstimated': 2816000000.0},
#  {'date': '2005-04-13',
#   'symbol': 'AAPL',
#   'eps': 0.0125,
#   'epsEstimated': 0.0075,
#   'time': 'amc',
#   'revenue': 3243000000.0,
#   'revenueEstimated': 2675474997.75},
#  {'date': '2005-01-12',
#   'symbol': 'AAPL',
#   'eps': 0.0125,
#   'epsEstimated': 0.0075,
#   'time': 'amc',
#   'revenue': 3490000000.0,
#   'revenueEstimated': 2879249998.5},
#  {'date': '2004-10-13',
#   'symbol': 'AAPL',
#   'eps': 0.005,
#   'epsEstimated': 0.0025,
#   'time': 'amc',
#   'revenue': 2350000000.0,
#   'revenueEstimated': 3172500000.0},
#  {'date': '2004-07-14',
#   'symbol': 'AAPL',
#   'eps': 0.0025,
#   'epsEstimated': 0.0025,
#   'time': 'amc',
#   'revenue': 2014000000.0,
#   'revenueEstimated': 2014000000.0},
#  {'date': '2004-04-14',
#   'symbol': 'AAPL',
#   'eps': 0.0025,
#   'epsEstimated': 0.0025,
#   'time': 'amc',
#   'revenue': 1909000000.0,
#   'revenueEstimated': 1909000000.0},
#  {'date': '2004-01-14',
#   'symbol': 'AAPL',
#   'eps': 0.0025,
#   'epsEstimated': 0.0025,
#   'time': 'amc',
#   'revenue': 2006000000.0,
#   'revenueEstimated': 2006000000.0},
#  {'date': '2003-10-15',
#   'symbol': 'AAPL',
#   'eps': 0.0025,
#   'epsEstimated': 0.0,
#   'time': 'amc',
#   'revenue': 1715000000.0,
#   'revenueEstimated': 0.0},
#  {'date': '2003-07-16',
#   'symbol': 'AAPL',
#   'eps': 0.000940388849799509,
#   'epsEstimated': 0.0,
#   'time': 'amc',
#   'revenue': 1545000000.0,
#   'revenueEstimated': 0.0},
#  {'date': '2003-04-16',
#   'symbol': 'AAPL',
#   'eps': 0.00069350051319038,
#   'epsEstimated': 0.0,
#   'time': 'amc',
#   'revenue': 1475000000.0,
#   'revenueEstimated': 0.0},
#  {'date': '2003-01-15',
#   'symbol': 'AAPL',
#   'eps': -0.000357,
#   'epsEstimated': 0.0,
#   'time': 'amc',
#   'revenue': 1472000000.0,
#   'revenueEstimated': 0.0},
#  {'date': '2002-10-16',
#   'symbol': 'AAPL',
#   'eps': -0.002,
#   'epsEstimated': 0.0,
#   'time': 'amc',
#   'revenue': 1443000000.0,
#   'revenueEstimated': 0.0},
#  {'date': '2002-07-16',
#   'symbol': 'AAPL',
#   'eps': 0.0025,
#   'epsEstimated': 0.0025,
#   'time': 'amc',
#   'revenue': 1429000000.0,
#   'revenueEstimated': 1429000000.0},
#  {'date': '2002-01-16',
#   'symbol': 'AAPL',
#   'eps': 0.0025,
#   'epsEstimated': 0.0025,
#   'time': 'amc',
#   'revenue': 1375000000.0,
#   'revenueEstimated': 1375000000.0},
#  {'date': '2001-04-18',
#   'symbol': 'AAPL',
#   'eps': 0.0025,
#   'epsEstimated': 0.0,
#   'time': 'amc',
#   'revenue': 1431000000.0,
#   'revenueEstimated': 0.0}]

# %%
df = pd.DataFrame()
for x in range(len(symbols)):
    res_df = pd.DataFrame(res[x].result())
    df = pd.concat([df, res_df])

# %%
print(df)
# Out:
#           date symbol   eps epsEstimated time       revenue   revenueEstimated
# 0   2021-11-22      A  1.21         1.17  amc  0.000000e+00       1461300000.0
# 1   2021-08-17      A   1.1         0.99  amc  1.586000e+09       1659210000.0
# 2   2021-05-25      A  0.71         0.83  amc  1.525000e+09  1745481927.710843
# 3   2021-02-16      A  0.94         0.89  amc  1.548000e+09  1461033707.865169
# 4   2020-11-23      A  0.72         0.93  amc  1.483000e+09  1817870967.741935
# ..         ...    ...   ...          ...  ...           ...                ...
# 22  2016-05-12   ZYNE -0.49        -0.56  bmo  7.250000e+03        8285.714286
# 23  2016-03-14   ZYNE -0.62        -0.29  bmo  4.927500e+04       23047.983871
# 24  2015-11-11   ZYNE -0.66        -0.38  bmo  1.994070e+05         194815.125
# 25  2015-08-27   ZYNE   NaN          NaN  bmo  1.539000e+04                0.0
# 26  2015-08-05   ZYNE   NaN          NaN  bmo  1.539000e+04                0.0
#
# [75540 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75540 entries, 0 to 26
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              75540 non-null  object
#  1   symbol            75540 non-null  object
#  2   eps               71820 non-null  object
#  3   epsEstimated      71419 non-null  object
#  4   time              75540 non-null  object
#  5   revenue           75540 non-null  float64
#  6   revenueEstimated  74322 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 4.6+ MB

# %%
df.to_csv("historical_earnings_calendar.csv")
